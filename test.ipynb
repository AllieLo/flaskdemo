# %%
import requests

# %%
url='https://data.epa.gov.tw/api/v2/aqx_p_02?api_key=e8dd42e6-9b8b-43f8-991e-b3dee723a52d&limit=1000&sort=datacreationdate%20desc&format=JSON'

# %%
resp=requests.get(url)
resp
# Out:
# <Response [200]>

# %% [markdown]
# ### 取得資料所在位置

# %%
datas=resp.json()['records']
datas
# Out:
# [{'site': '大城',
#   'county': '彰化縣',
#   'pm25': '28',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '富貴角',
#   'county': '新北市',
#   'pm25': '16',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '麥寮',
#   'county': '雲林縣',
#   'pm25': '22',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '關山',
#   'county': '臺東縣',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬公',
#   'county': '澎湖縣',
#   'pm25': '9',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '金門',
#   'county': '金門縣',
#   'pm25': '8',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '馬祖',
#   'county': '連江縣',
#   'pm25': '22',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '埔里',
#   'county': '南投縣',
#   'pm25': '33',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '復興',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '永和',
#   'county': '新北市',
#   'pm25': '19',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹山',
#   'county': '南投縣',
#   'pm25': '63',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中壢',
#   'county': '桃園市',
#   'pm25': '24',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三重',
#   'county': '新北市',
#   'pm25': '26',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '冬山',
#   'county': '宜蘭縣',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '宜蘭',
#   'county': '宜蘭縣',
#   'pm25': '17',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '陽明',
#   'county': '臺北市',
#   'pm25': '22',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '花蓮',
#   'county': '花蓮縣',
#   'pm25': '15',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺東',
#   'county': '臺東縣',
#   'pm25': '5',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '恆春',
#   'county': '屏東縣',
#   'pm25': '0',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '潮州',
#   'county': '屏東縣',
#   'pm25': '10',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '屏東',
#   'county': '屏東縣',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '小港',
#   'county': '高雄市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前鎮',
#   'county': '高雄市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '前金',
#   'county': '高雄市',
#   'pm25': '9',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '左營',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '楠梓',
#   'county': '高雄市',
#   'pm25': '7',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林園',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大寮',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '鳳山',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '仁武',
#   'county': '高雄市',
#   'pm25': '11',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '橋頭',
#   'county': '高雄市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '美濃',
#   'county': '高雄市',
#   'pm25': '12',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺南',
#   'county': '臺南市',
#   'pm25': '14',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '安南',
#   'county': '臺南市',
#   'pm25': '16',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '善化',
#   'county': '臺南市',
#   'pm25': '18',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新營',
#   'county': '臺南市',
#   'pm25': '39',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '嘉義',
#   'county': '嘉義市',
#   'pm25': '40',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '臺西',
#   'county': '雲林縣',
#   'pm25': '19',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '朴子',
#   'county': '嘉義縣',
#   'pm25': '23',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新港',
#   'county': '嘉義縣',
#   'pm25': '37',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '崙背',
#   'county': '雲林縣',
#   'pm25': '49',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '斗六',
#   'county': '雲林縣',
#   'pm25': '59',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '南投',
#   'county': '南投縣',
#   'pm25': '50',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '二林',
#   'county': '彰化縣',
#   'pm25': '56',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '線西',
#   'county': '彰化縣',
#   'pm25': '41',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '彰化',
#   'county': '彰化縣',
#   'pm25': '37',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '西屯',
#   'county': '臺中市',
#   'pm25': '44',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '忠明',
#   'county': '臺中市',
#   'pm25': '40',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大里',
#   'county': '臺中市',
#   'pm25': '39',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '沙鹿',
#   'county': '臺中市',
#   'pm25': '42',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '豐原',
#   'county': '臺中市',
#   'pm25': '37',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '三義',
#   'county': '苗栗縣',
#   'pm25': '36',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '苗栗',
#   'county': '苗栗縣',
#   'pm25': '38',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '頭份',
#   'county': '苗栗縣',
#   'pm25': '30',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新竹',
#   'county': '新竹市',
#   'pm25': '26',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '竹東',
#   'county': '新竹縣',
#   'pm25': '34',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '湖口',
#   'county': '新竹縣',
#   'pm25': '29',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '龍潭',
#   'county': '桃園市',
#   'pm25': '38',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '平鎮',
#   'county': '桃園市',
#   'pm25': '25',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '觀音',
#   'county': '桃園市',
#   'pm25': '17',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大園',
#   'county': '桃園市',
#   'pm25': '19',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '桃園',
#   'county': '桃園市',
#   'pm25': '23',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '大同',
#   'county': '臺北市',
#   'pm25': '25',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '松山',
#   'county': '臺北市',
#   'pm25': '16',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '古亭',
#   'county': '臺北市',
#   'pm25': '24',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬華',
#   'county': '臺北市',
#   'pm25': '22',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '中山',
#   'county': '臺北市',
#   'pm25': '17',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '士林',
#   'county': '臺北市',
#   'pm25': '26',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '淡水',
#   'county': '新北市',
#   'pm25': '17',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '林口',
#   'county': '新北市',
#   'pm25': '18',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '菜寮',
#   'county': '新北市',
#   'pm25': '29',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新莊',
#   'county': '新北市',
#   'pm25': '25',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '板橋',
#   'county': '新北市',
#   'pm25': '28',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '土城',
#   'county': '新北市',
#   'pm25': '37',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '新店',
#   'county': '新北市',
#   'pm25': '16',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '萬里',
#   'county': '新北市',
#   'pm25': '26',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '汐止',
#   'county': '新北市',
#   'pm25': '23',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'},
#  {'site': '基隆',
#   'county': '基隆市',
#   'pm25': '17',
#   'datacreationdate': '2023-04-18 19:00',
#   'itemunit': 'μg/m3'}]

# %%
len(datas)
# Out:
# 78

# %%
datas[0]
# Out:
# {'site': '大城',
#  'county': '彰化縣',
#  'pm25': '28',
#  'datacreationdate': '2023-04-18 19:00',
#  'itemunit': 'μg/m3'}
